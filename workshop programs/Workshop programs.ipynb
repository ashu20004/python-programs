# %%
a=200
b=1199
print(a+b)
# Out:
# 1399

# %%
print(not False)

# %%
a=input()
print(type(a))
# Out:
# Ashu
# <class 'str'>

# %%
a=int(input("Enter value of A:"))
b=int(input("Enter value of B:"))
c=a+b
print("Sum of {} and {} ={}".format(a,b,a+b))
# Out:
# Enter value of A:12
# Enter value of B:13
# Sum of 12 and 13 =25

# %%
name=str(input("Enter Your name:"))
print("Hii {}!".format(name))
"""print("Hii",name,"!")"""
# Out:
# Enter Your name:Ashu
# Hii Ashu!

# %%
print(type(name))
print(type(c))
print(type(False))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %%
a=100
b=200
if a>b:
  print("{} is greater than {}".format(a,b))
elif a==b:
  print("{} and {} are equal".format(a,b))
else:
  print("{} is greater than {}".format(b,a))
# Out:
# 200 is greater than 100

# %%
# !python --version
# Out:
# Python 3.8.16

# %%
a=float(input("Enter frist number:"))
b=float(input("Enter Second number:"))
c=float(input("Enter Third number:"))
if a>b:
  if a>c:
    print("a is greatest")
  else:
    print("c is greatest")
elif a==b:
  if b==c:
    print("a,b and c are equal")
  else:
    print("c is greatest")
else:
  if b>c:
    print("b is greatest")
  else:
    print("c is greatest")
# Out:
# Enter frist number:12
# Enter Second number:12
# Enter Third number:12
# a,b and c are equal

# %%
a=float(input("Enter a number:"))
b=float(input("Enter second number:"))
rem=a%b
quo=a//b
print("Reminder of a and b=",rem,"\nQuotient of a and b =",quo)
# Out:
# Enter a number:12
# Enter second number:144
# Reminder of a and b= 12.0
# Quotient of a and b = 0.08333333333333333

# %% [markdown]
# Workshop progarm

# %%
#1.WAP to add two numbers
a=5
b=10
print(a+b)

# %%
#2.WAP to Read and print quotient and reminder
a=int(input("Enter first number:"))
b=int(input("Enter Second number:"))
print("Quotient of a and b=",a//b,"\nReminder of a and b=",a%b)
# Out:
# Enter first number:12
# Enter Second number:2
# Quotient of a and b= 6
# Reminder of a and b= 0

# %%
#3.WAP to find average of Three numbe
a=int(input("Enter first number:"))
b=int(input("Enter Second number:"))
c=int(input("Enter Third number:"))
ave=(a+b+c)/3
print("Average of a,b and c=",ave)
# Out:
# Enter first number:12
# Enter Second number:13
# Enter Third number:14
# Average of a,b and c= 13.0

# %%
#4.WAP to Calculate total marks of 5 subjects and find percentage
a=int(input("Enter Science number:"))
b=int(input("Enter Maths number:"))
c=int(input("Enter English number:"))
d=int(input("Enter Hindi number:"))
e=int(input("Enter Computer number:"))
total=a+b+c+d+e
per=(total/500)*100
print("Total marks out of 500=",total,"\nPercentage=",per)
# Out:
# Enter Science number:33
# Enter Maths number:33
# Enter English number:33
# Enter Hindi number:33
# Enter Computer number:33
# Total mrks out of 500= 165
# Percentage= 33.0

# %%
#5.WAP to find gross salary
basic=int(input("Enter your Basic salary"))
da=(50/100)*basic
hra=(20/100)*basic
gross=basic+da+hra
print("Gross salary of",basic,"=",gross)

# %%
#6.WAP to calculate Area of Circle
radius=float(input("Enter radius of circle:"))
area=(2*(22/7)*(radius**2))
print("Area of circle=",area)
# Out:
# Enter radius of circle:1
# Area of circle= 6.285714285714286

# %%
#7.WAP to Calculate area of rectangle
len=float(input("Enter length of Rectangle:"))
wid=float(input("Enter width of Rectangle:"))
print("Area of Rectangle=",len*wid)
# Out:
# Enter length of Rectangle:12
# Enter width of Rectangle:12
# Area of Rectangle= 144.0

# %%
#8.WAP to calcualte area of Square
side=float(input("Enter side of Square:"))
area=side**2
print("Area of Square=",area)
# Out:
# Enter side of Square2
# Area of Square= 4.0

# %%
#9.WAP to calculate area and ccircumference of circle
radius=float(input("Enter radius of circle:"))
area=(2*(22/7)*(radius**2))
circ=2*(22/7)*radius
print("Area of circle=",area,"\nCircumfernce of circle =",circ)
# Out:
# Enter radius of circle:2
# Area of circle= 25.142857142857142
# Circumfernce of circle = 12.571428571428571

# %%
#10.WAP to find Area of Scalene triangle
a=float(input("Enter Longest side:"))
b=float(input("Enter Shorter side:"))
c=float(input("Enter Shortest side:"))
s=(a+b+c)/2
print("Area of Scalene Triangle =",(s*(s-a)*(s-b)*(s-c))**0.5)
# Out:
# Enter Longest side:9
# Enter Shorter side:7
# Enter Shortest side:5
# Area of Triangle = 17.41228014936585

# %%
#11.WAP to calculate the area of Right-angle Triangle.
b=float(input("Enter Base:"))
c=float(input("Enter Height:"))
area=0.5*b*c
print("Area of Right-angle Triangle:",area)
# Out:
# Enter Base:2
# Enter Height:1
# Area of Right-angle Triangle: 1.0

# %%
#12.WAP to Find area of trapezium.
a=float(input("Enter Small || side:"))
b=float(input("Enter Bigger || side:"))
c=float(input("Enter slant hight:"))
d=(b-a)/2
h=(c**2-d**2)**0.5
area=0.5*(a+b)*h
print("Area of Trapezium =",area)
# Out:
# Enter small || side:12
# Enter Bigger || side:14
# Enter slant hight:3
# Area of Trapezium = 36.76955262170048

# %%
#13.WAP to find area of rhombus.
side=float(input("Enter side of Rhombus:"))
area=()

# %%
#14.WAP to find area of parallelogram.
a=float(input("Enter Longer side:"))
b=float(input("Enter Smaller side:"))
print("Area of parallelogram =",a*b)
# Out:
# Enter Longer side:12
# Enter Smaller side:3
# Area of parallelogram = 36.0

# %%
#15.WAP to find volume and surface area of cube.
a=float(input("Enter Side of cube:"))
area=6*(a**2)
volume=a**3
print("Area of cube =",area,"\nVolume of Cube =",volume)

# %%
#16.WAP to find area and volume of Cuboid.
a=float(input("Enter length:"))
b=float(input("Enter width:"))
c=float(input("Enter height:"))
area=2*(a*b+b*c+c*a)
volume=a*b*c
print("Area of cuboid =",area,"\nVolume of cuboid =",volume)
# Out:
# Enter length:2
# Enter width:3
# Enter height:1
# Area of cuboid = 22.0 Volume of cuboid = 6.0

# %%
#17.WAP to find area and volume of cylinder.
a=float(input("Enter Radius of cylinder:"))
b=float(input("Enter height of Cylinder:"))
area=2*(22/7)*a*(a+b)
volume=(22/7)*a**2*b
print("Area of cylinder =",area,"\nVolume of Cylinder =",volume)
# Out:
# Enter Radius of cylinder:1
# Enter height of Cylinder:2
# Area of cylinder = 18.857142857142858
# Volume of Cylinder = 6.285714285714286

# %%
#18.WAP to find area and volume of cone.
a=float(input("Enter slant height:"))
b=float(input("Enter radius :"))
area=(22/7)*a*b
h=(a**2-b**2)**0.5
volume=(1/3)*(22/7)*(b**2)*h
print("Area of cone =",area,"\nVolume of cone =",volume)
# Out:
# Enter slant height:1
# Enter radius :2
# Area of cone = 6.285714285714286
# Volume of cone = (4.444315286085323e-16+7.258117669812437j)

# %%
#19.WAP to find area and volume of sphere.
a=float(input("Enter radius:"))
area=4*(22/7)*(a**2)
volume=(4/3)*(22/7)*(a**3)
print("Area of sphere =",area,"\nVolume of sphere =",volume)
# Out:
# Enter radius:2
# Area of sphere = 50.285714285714285
# Volume of sphere = 33.52380952380952

# %%
#20.WAP to find perimeter of circle, rectangle and triangle.
a=float(input("Enter radius of circle:"))
b=float(input("Enter lenght of rectangle:"))
c=float(input("Enter width of rectangle:"))
d=float(input("Enter base of triangle:"))
e=float(input("Enter height of triangle:"))
f=float(input("Enter Hypoteneus of triangle:"))
print("perimeter of circle =",2*(22/7)*a)
print("Perimeter of rectangle =",2*(b+c))
print("Perimeter of triangle =",(d+e+f))

# %%
#21.WAP to compute simple interest.
a=float(input("Enter Principle rate:"))
b=float(input("Enter rate:"))
c=float(input("Enter time in years:"))
si=(a*b*c)/100
print("simple interest =",si)
# Out:
# Enter Principle rate:1
# Enter rate:2
# Enter time:1
# simple interest = 0.02

# %%
#22.WAP to convert fahernheit to celsius.
a=float(input("Enter temperature in Fahernheit ="))
print("temperatue in celsius =",((a-32)*5)/9)

# %%
#23.WAP to find Gravitational Force acting between Two Objects.
m1=float(input("Enter mass of first object:"))
m2=float(input("Enter mass of second object:"))
d=float(input("Enter distance between obj1 andd obj2:"))
G=float(input("Enter Gravitational force acting between them:"))
GF=(m1*m2*G)/d
print("Gravitational force =",GF)

# %%
#24.WAP to swap two variable.
a=input("Enter any value or chracter:")
b=input("Enter any other value or chracter:")
temp=a
a=b
b=temp
print("First input=",a,"\nsecond input =",b)

# %%
#25.WAP to swap two values without using third variable.
a=float(input("Enter any value :"))
b=float(input("Enter any other value:"))
a=a+b
b=a-b
a=a-b
print("first input =",a,"second input =",b)

# %%
#26.WAP to copy value to another variable.
a=25
b=a
print("Value of",b,"=",a)
# Out:
# Value of 25 = 25

# %%
#27.WAP to perform modulo divisio on a=8 and b=3.
a=8
b=3
print(a%b)

# %%
#28.WAP to perform modulo divisio on a=-8 and b=3.
a=-8
b=3
print(a%b)

# %%
#29.WAP to perform modulo divisio on a=8 and b=-3.
a=8
b=-3
print(a%b)

# %%
#30.WAP to perform modulo divisio on a=-8 and b=-3.
a=-8
b=-3
print(a%b)

# %%
#31.WAP to apply greater than operator on a=8 and b=3.
a=8
b=3
print(a>b)
# Out:
# True

# %%
#32.WAP to apply greater than operator on a=8 and b=3.
a=8
b=3
print(a<b)
# Out:
# False

# %%
#33.WAP to apply greater than and equal to operator on a=8 and b=3.
a=8
b=3
print(a>b ,a==b)
# Out:
# True False

# %%
#34.WAP to apply less than and equal to operator on a=8 and b=3.
a=8
b=3
print(a<b,a==b)
# Out:
# False False

# %%
#35.WAP to apply greater than operator on a=8 and b=3.
a=8
b=3
print(a<b,a==b)
#not completed yet
